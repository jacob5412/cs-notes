# %% [markdown]
# # Problem Statement
#
#     Your client is an Insurance company and they need your help in building a model to predict whether the policyholder (customer) will pay next premium on time or not.

# %% [markdown]
# # Variable	Definition
#
# 1.  **id** : Unique ID of the policy
#
# 1.  **perc_premium_paid_by_cash_credit** : Percentage of premium amount paid by cash or credit card
#
# 1.  **age_in_days** : Age in days of policy holder
#
# 1.  **Income** : Monthly Income of policy holder
#
# 1.  **Count_3-6_months_late** : No of premiums late by 3 to 6 months
#
# 1.  **Count_6-12_months_late** : No  of premiums late by 6 to 12 months
#
# 1.  **Count_more_than_12_months_late** : No of premiums late by more than 12 months
#
# 1.  **application_underwriting_score** : Underwriting Score of the applicant at the time of application (No applications under the score of 90 are insured)
#
# 1.  **no_of_premiums_paid** : Total premiums paid on time till now
#
# 1.  **sourcing_channel** : Sourcing channel for application
#
# 1.  **residence_area_type** : Area type of Residence (Urban/Rural)
#
# 1.  **target** : 1 - premium paid on time, 0 - otherwise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('train_qnU1GcL.csv')
df = df_train.copy()
df_test = pd.read_csv('test_QaJU1Mh.csv')
df.head(15).T
# Out:
#                                       0       1       2       3       4   \
# id                                110936   41492   31300   19415   99379
# perc_premium_paid_by_cash_credit  0.4290  0.0100  0.9170  0.0490  0.0520
# age_in_days                        12058   21546   17531   15341   31400
# Income                            355060  315150   84140  250510  198680
# Count_3-6_months_late             0.0000  0.0000  2.0000  0.0000  0.0000
# Count_6-12_months_late            0.0000  0.0000  3.0000  0.0000  0.0000
# Count_more_than_12_months_late    0.0000  0.0000  1.0000  0.0000  0.0000
# application_underwriting_score   99.0200 99.8900 98.6900 99.5700 99.8700
# no_of_premiums_paid                   13      21       7       9      12
# sourcing_channel                       C       A       C       A       B
# residence_area_type                Urban   Urban   Rural   Urban   Urban
# target                                 1       1       0       1       1
#
#                                       5       6       7       8       9   \
# id                                 59951   54031   94290   93730   84844
# perc_premium_paid_by_cash_credit  0.5400  1.0000  1.0000  0.6210  0.9080
# age_in_days                        17527   24829   21911    9868   23008
# Income                            282080  118400  180240   92520  107180
# Count_3-6_months_late             2.0000  0.0000  1.0000  0.0000  2.0000
# Count_6-12_months_late            0.0000  0.0000  6.0000  0.0000  0.0000
# Count_more_than_12_months_late    0.0000  0.0000  4.0000  0.0000  0.0000
# application_underwriting_score   99.1800 99.0500 99.3300 99.5800 98.9100
# no_of_premiums_paid                    9      11       3       4      11
# sourcing_channel                       B       B       A       A       A
# residence_area_type                Rural   Urban   Urban   Urban   Rural
# target                                 1       1       0       1       0
#
#                                       10      11      12      13      14
# id                                 87400   51808  104167   52420   42421
# perc_premium_paid_by_cash_credit  0.0510  0.0330  1.0000  0.1110  0.0270
# age_in_days                        17529   16075   16436   19723   16430
# Income                            200100  122060   27290  136000  114110
# Count_3-6_months_late             1.0000  0.0000  1.0000  0.0000  0.0000
# Count_6-12_months_late            0.0000  0.0000  0.0000  0.0000  0.0000
# Count_more_than_12_months_late    0.0000  0.0000  1.0000  0.0000  1.0000
# application_underwriting_score   98.6600 97.0300 98.3200 99.5900 98.7000
# no_of_premiums_paid                   22       7       4       9      13
# sourcing_channel                       C       B       A       A       D
# residence_area_type                Rural   Urban   Urban   Urban   Urban
# target                                 1       1       1       1       1

# %%
df.shape
# Out:
# (79853, 12)

# %%
df.describe().T
# Out:
#                                       count        mean         std  \
# id                               79853.0000  57167.1664  32928.9702
# perc_premium_paid_by_cash_credit 79853.0000      0.3143      0.3349
# age_in_days                      79853.0000  18846.6969   5208.7191
# Income                           79853.0000 208847.1712 496582.5973
# Count_3-6_months_late            79756.0000      0.2487      0.6915
# Count_6-12_months_late           79756.0000      0.0782      0.4365
# Count_more_than_12_months_late   79756.0000      0.0600      0.3120
# application_underwriting_score   76879.0000     99.0673      0.7398
# no_of_premiums_paid              79853.0000     10.8639      5.1707
# target                           79853.0000      0.9374      0.2422
#
#                                         min         25%         50%  \
# id                                   2.0000  28640.0000  57262.0000
# perc_premium_paid_by_cash_credit     0.0000      0.0340      0.1670
# age_in_days                       7670.0000  14974.0000  18625.0000
# Income                           24030.0000 108010.0000 166560.0000
# Count_3-6_months_late                0.0000      0.0000      0.0000
# Count_6-12_months_late               0.0000      0.0000      0.0000
# Count_more_than_12_months_late       0.0000      0.0000      0.0000
# application_underwriting_score      91.9000     98.8100     99.2100
# no_of_premiums_paid                  2.0000      7.0000     10.0000
# target                               0.0000      1.0000      1.0000
#
#                                          75%           max
# id                                85632.0000   114076.0000
# perc_premium_paid_by_cash_credit      0.5380        1.0000
# age_in_days                       22636.0000    37602.0000
# Income                           252090.0000 90262600.0000
# Count_3-6_months_late                 0.0000       13.0000
# Count_6-12_months_late                0.0000       17.0000
# Count_more_than_12_months_late        0.0000       11.0000
# application_underwriting_score       99.5400       99.8900
# no_of_premiums_paid                  14.0000       60.0000
# target                                1.0000        1.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79853 entries, 0 to 79852
# Data columns (total 12 columns):
# id                                  79853 non-null int64
# perc_premium_paid_by_cash_credit    79853 non-null float64
# age_in_days                         79853 non-null int64
# Income                              79853 non-null int64
# Count_3-6_months_late               79756 non-null float64
# Count_6-12_months_late              79756 non-null float64
# Count_more_than_12_months_late      79756 non-null float64
# application_underwriting_score      76879 non-null float64
# no_of_premiums_paid                 79853 non-null int64
# sourcing_channel                    79853 non-null object
# residence_area_type                 79853 non-null object
# target                              79853 non-null int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 7.3+ MB

# %%
df.isnull().sum()
# Out:
# id                                     0
# perc_premium_paid_by_cash_credit       0
# age_in_days                            0
# Income                                 0
# Count_3-6_months_late                 97
# Count_6-12_months_late                97
# Count_more_than_12_months_late        97
# application_underwriting_score      2974
# no_of_premiums_paid                    0
# sourcing_channel                       0
# residence_area_type                    0
# target                                 0
# dtype: int64

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ## id

# %%
df.id.describe()
# Out:
# count    79853.0000
# mean     57167.1664
# std      32928.9702
# min          2.0000
# 25%      28640.0000
# 50%      57262.0000
# 75%      85632.0000
# max     114076.0000
# Name: id, dtype: float64

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.distplot(df.id)

# %% [markdown]
# ## perc_premium_paid_by_cash_credit

# %%
pd.options.display.float_format = '{:.4f}'.format
df.perc_premium_paid_by_cash_credit.describe(percentiles=[0,.25,.5,.75,.9,.99,1])
# Out:
# count   79853.0000
# mean        0.3143
# std         0.3349
# min         0.0000
# 0%          0.0000
# 25%         0.0340
# 50%         0.1670
# 75%         0.5380
# 90%         0.9250
# 99%         1.0000
# 100%        1.0000
# max         1.0000
# Name: perc_premium_paid_by_cash_credit, dtype: float64

# %%
df.query('perc_premium_paid_by_cash_credit==1')['target'].value_counts()
# Out:
# 1    4025
# 0     979
# Name: target, dtype: int64

# %%
df.perc_premium_paid_by_cash_credit.value_counts().head()
# Out:
# 0.0000    5723
# 1.0000    5004
# 0.0010     698
# 0.0020     612
# 0.0030     551
# Name: perc_premium_paid_by_cash_credit, dtype: int64

# %%
sns.boxplot(df.perc_premium_paid_by_cash_credit);

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.distplot(df.perc_premium_paid_by_cash_credit);

# %% [markdown]
# -  Values are decreasing between 0 and 1, there is a sudden spike at 0 and 1.

# %% [markdown]
# ## age_in_days

# %%
df.age_in_days.describe()
# Out:
# count   79853.0000
# mean    18846.6969
# std      5208.7191
# min      7670.0000
# 25%     14974.0000
# 50%     18625.0000
# 75%     22636.0000
# max     37602.0000
# Name: age_in_days, dtype: float64

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.distplot(df.age_in_days);
plt.xscale('log')

# %% [markdown]
# -  Ages are normally distributed.

# %% [markdown]
# ## Income

# %%
pd.options.display.float_format = '{:.4f}'.format
df.Income.describe(percentiles=[0,0.25,0.5,0.75,0.9,0.99,.999,1])
# Out:
# count      79853.0000
# mean      208847.1712
# std       496582.5973
# min        24030.0000
# 0%         24030.0000
# 25%       108010.0000
# 50%       166560.0000
# 75%       252090.0000
# 90%       357414.0000
# 99%       771078.0000
# 99.9%    2413366.9600
# 100%    90262600.0000
# max     90262600.0000
# Name: Income, dtype: float64

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(df.Income);
plt.xscale('log')

# %% [markdown]
# - Many outliers on the right of the 75th quantile.

# %% [markdown]
# ## Count_3-6_months_late

# %%
df['Count_3-6_months_late'].describe()
# Out:
# count   79756.0000
# mean        0.2487
# std         0.6915
# min         0.0000
# 25%         0.0000
# 50%         0.0000
# 75%         0.0000
# max        13.0000
# Name: Count_3-6_months_late, dtype: float64

# %%
sns.countplot(df['Count_3-6_months_late']);
plt.yscale('log')

# %% [markdown]
# - Decreasing

# %% [markdown]
# ## Count_6-12_months_late

# %%
df['Count_6-12_months_late'].describe()
# Out:
# count   79756.0000
# mean        0.0782
# std         0.4365
# min         0.0000
# 25%         0.0000
# 50%         0.0000
# 75%         0.0000
# max        17.0000
# Name: Count_6-12_months_late, dtype: float64

# %%
sns.countplot(df['Count_6-12_months_late']);
plt.yscale('log')

# %% [markdown]
# - Decreasing number of late payee

# %% [markdown]
# ## Count_more_than_12_months_late

# %%
df['Count_more_than_12_months_late'].describe()
# Out:
# count   79756.0000
# mean        0.0600
# std         0.3120
# min         0.0000
# 25%         0.0000
# 50%         0.0000
# 75%         0.0000
# max        11.0000
# Name: Count_more_than_12_months_late, dtype: float64

# %%
sns.countplot(df['Count_more_than_12_months_late']);
plt.yscale('log')

# %% [markdown]
# - Decreasing number of late payee

# %% [markdown]
# ## application_underwriting_score

# %%
df['application_underwriting_score'].describe()
# Out:
# count   76879.0000
# mean       99.0673
# std         0.7398
# min        91.9000
# 25%        98.8100
# 50%        99.2100
# 75%        99.5400
# max        99.8900
# Name: application_underwriting_score, dtype: float64

# %%
sns.distplot(df.loc[df['application_underwriting_score'].notnull(),'application_underwriting_score']);

# %% [markdown]
# ## no_of_premiums_paid

# %%
df['no_of_premiums_paid'].describe()
# Out:
# count   79853.0000
# mean       10.8639
# std         5.1707
# min         2.0000
# 25%         7.0000
# 50%        10.0000
# 75%        14.0000
# max        60.0000
# Name: no_of_premiums_paid, dtype: float64

# %%
sns.distplot(df.loc[df['no_of_premiums_paid'].notnull(),'no_of_premiums_paid']);

# %% [markdown]
# ## Count_premium_paid (derived)

# %%
df['Count_premium_paid'] = df['no_of_premiums_paid'] + (df['Count_more_than_12_months_late'] + df['Count_6-12_months_late'] + df['Count_3-6_months_late'])

# %%
df['Count_premium_paid'].describe()
# Out:
# count   79756.0000
# mean       11.2615
# std         5.2739
# min         2.0000
# 25%         8.0000
# 50%        10.0000
# 75%        14.0000
# max        60.0000
# Name: Count_premium_paid, dtype: float64

# %%
sns.countplot(df['Count_premium_paid']);
plt.yscale('log')

# %% [markdown]
# - Decreasing number of late payee

# %% [markdown]
# ## sourcing_channel

# %%
df['sourcing_channel'].describe()
# Out:
# count     79853
# unique        5
# top           A
# freq      43134
# Name: sourcing_channel, dtype: object

# %%
sns.countplot(df['sourcing_channel']);

# %% [markdown]
# ## residence_area_type

# %%
df['residence_area_type'].describe()
# Out:
# count     79853
# unique        2
# top       Urban
# freq      48183
# Name: residence_area_type, dtype: object

# %%
sns.countplot(df['residence_area_type']);

# %% [markdown]
# ## age_in_years (derived)

# %%
df['age_in_years'] = df['age_in_days'].apply(lambda x: x//365)

# %%
df.age_in_years.describe(percentiles=[0,.25,.5,.75,.9,.99,.999,1])
# Out:
# count   79853.0000
# mean       51.6074
# std        14.2705
# min        21.0000
# 0%         21.0000
# 25%        41.0000
# 50%        51.0000
# 75%        62.0000
# 90%        71.0000
# 99%        86.0000
# 99.9%      92.0000
# 100%      103.0000
# max       103.0000
# Name: age_in_years, dtype: float64

# %% [markdown]
# - max age is 103.

# %%
df.query('age_in_years > 99')
# Out:
#            id  perc_premium_paid_by_cash_credit  age_in_days  Income  \
# 5045     7248                            0.0100        37240   99060
# 19085   67942                            0.1100        37239  102580
# 26029   48348                            0.0260        36870   50050
# 38401   44175                            0.0030        36874   86570
# 38441  111319                            1.0000        37602   48130
#
#        Count_3-6_months_late  Count_6-12_months_late  \
# 5045                  0.0000                  0.0000
# 19085                 0.0000                  0.0000
# 26029                 0.0000                  0.0000
# 38401                 2.0000                  0.0000
# 38441                 0.0000                  0.0000
#
#        Count_more_than_12_months_late  application_underwriting_score  \
# 5045                           0.0000                         99.8900
# 19085                          0.0000                         99.2700
# 26029                          0.0000                         99.8700
# 38401                          0.0000                             nan
# 38441                          0.0000                             nan
#
#        no_of_premiums_paid sourcing_channel residence_area_type  target  \
# 5045                     5                A               Urban       1
# 19085                    9                B               Urban       1
# 26029                    7                A               Rural       1
# 38401                    8                A               Rural       0
# 38441                    5                A               Rural       1
#
#        Count_premium_paid  age_in_years
# 5045               5.0000           102
# 19085              9.0000           102
# 26029              7.0000           101
# 38401             10.0000           101
# 38441              5.0000           103

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.distplot(df.age_in_years);

# %% [markdown]
# -  Ages are normally distributed.

# %% [markdown]
# ## target

# %%
df['target'].describe()
# Out:
# count   79853.0000
# mean        0.9374
# std         0.2422
# min         0.0000
# 25%         1.0000
# 50%         1.0000
# 75%         1.0000
# max         1.0000
# Name: target, dtype: float64

# %%
sns.countplot(df['target']);

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Correlation

# %%
#Using seaborn set to plot heatmap
sns.set(rc={'figure.figsize':(12,10), 'figure.dpi':200})
cr = df.drop(columns=['id']).corr()
with sns.axes_style("whitegrid"):
    sns.heatmap( cr, cmap='Spectral_r', annot=True, square=False, linewidth=.1);

# %% [markdown]
# ## target vs perc_premium_paid_by_cash_credit

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(y='perc_premium_paid_by_cash_credit',x='target',data=df);

# %% [markdown]
# -  Can be binned two three bins

# %% [markdown]
# ## target vs Count_3-6_months_late

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(df['target'],df['Count_3-6_months_late']);

# %%
df.loc[df.target == 0,'Count_3-6_months_late'].value_counts()
# Out:
# 0.0000     2627
# 1.0000     1153
# 2.0000      592
# 3.0000      288
# 4.0000      158
# 5.0000       67
# 6.0000       31
# 7.0000       10
# 8.0000        6
# 9.0000        2
# 10.0000       1
# 11.0000       1
# 12.0000       1
# 13.0000       1
# Name: Count_3-6_months_late, dtype: int64

# %%
df.loc[df.target == 1,'Count_3-6_months_late'].value_counts()
# Out:
# 0.0000    64174
# 1.0000     7673
# 2.0000     1927
# 3.0000      666
# 4.0000      216
# 5.0000      101
# 6.0000       37
# 7.0000       13
# 8.0000        9
# 9.0000        2
# Name: Count_3-6_months_late, dtype: int64

# %% [markdown]
# ## target vs Count_6-12_months_late

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(df['target'],df['Count_6-12_months_late']);

# %%
df.loc[df.target == 0,'Count_6-12_months_late'].value_counts()
# Out:
# 0.0000     3445
# 1.0000      828
# 2.0000      334
# 3.0000      185
# 4.0000       85
# 5.0000       30
# 6.0000       13
# 7.0000        7
# 8.0000        3
# 9.0000        2
# 17.0000       1
# 12.0000       1
# 13.0000       1
# 14.0000       1
# 11.0000       1
# 10.0000       1
# Name: Count_6-12_months_late, dtype: int64

# %%
df.loc[df.target == 1,'Count_6-12_months_late'].value_counts()
# Out:
# 0.0000     72386
# 1.0000      1852
# 2.0000       359
# 3.0000       132
# 4.0000        45
# 5.0000        16
# 6.0000        13
# 7.0000         4
# 10.0000        3
# 9.0000         2
# 8.0000         2
# 15.0000        1
# 13.0000        1
# 11.0000        1
# 14.0000        1
# Name: Count_6-12_months_late, dtype: int64

# %% [markdown]
# ## target vs Count_more_than_12_months_late

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(df['target'],df['Count_more_than_12_months_late']);

# %%
df.loc[df.target==0,'Count_more_than_12_months_late'].value_counts()
# Out:
# 0.0000     3750
# 1.0000      835
# 2.0000      228
# 3.0000       85
# 4.0000       25
# 5.0000        7
# 6.0000        4
# 7.0000        2
# 8.0000        1
# 11.0000       1
# Name: Count_more_than_12_months_late, dtype: int64

# %%
df.loc[df.target == 1,'Count_more_than_12_months_late'].value_counts()
# Out:
# 0.0000    72288
# 1.0000     2161
# 2.0000      270
# 3.0000       66
# 4.0000       23
# 5.0000        6
# 6.0000        2
# 7.0000        1
# 8.0000        1
# Name: Count_more_than_12_months_late, dtype: int64

# %% [markdown]
# ## target vs Count_premium_paid

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.boxplot(df['target'],df['Count_premium_paid']);

# %%
df.loc[(df.Count_premium_paid > 0),'target'].value_counts()
# Out:
# 1    74818
# 0     4938
# Name: target, dtype: int64

# %%
df.loc[df.target==0,'Count_premium_paid'].value_counts().sum()
# Out:
# 4938

# %%
df.loc[df.target == 1,'Count_premium_paid'].value_counts().sum()
# Out:
# 74818

# %% [markdown]
# ## target vs sourcing_channel

# %%
df.loc[df.sourcing_channel=='A' ,'target'].value_counts()
# Out:
# 1    40785
# 0     2349
# Name: target, dtype: int64

# %%
df.loc[df.sourcing_channel=='B' ,'target'].value_counts()
# Out:
# 1    15446
# 0     1066
# Name: target, dtype: int64

# %%
df.loc[df.sourcing_channel=='C' ,'target'].value_counts()
# Out:
# 1    11136
# 0      903
# Name: target, dtype: int64

# %%
df.loc[df.sourcing_channel=='D' ,'target'].value_counts()
# Out:
# 1    6925
# 0     634
# Name: target, dtype: int64

# %%
df.loc[df.sourcing_channel=='E' ,'target'].value_counts()
# Out:
# 1    563
# 0     46
# Name: target, dtype: int64

# %% [markdown]
# -  Sourcing_channel are ordinal categorical variables

# %% [markdown]
# ## target vs age_in_years

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.stripplot(x=df['target'],y=df['age_in_years'],jitter=True, dodge=True, alpha=0.075);

# %% [markdown]
# ## target vs application_underwriting_score

# %%
df.loc[df.target==0,['application_underwriting_score']].describe()
# Out:
#        application_underwriting_score
# count                       4798.0000
# mean                          98.8703
# std                            0.8777
# min                           92.2400
# 25%                           98.5300
# 50%                           99.0500
# 75%                           99.4800
# max                           99.8900

# %%
df.loc[df.target==1,['application_underwriting_score']].describe()
# Out:
#        application_underwriting_score
# count                      72081.0000
# mean                          99.0804
# std                            0.7278
# min                           91.9000
# 25%                           98.8300
# 50%                           99.2200
# 75%                           99.5400
# max                           99.8900

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
sns.stripplot(x=df['target'],y=df['application_underwriting_score'],jitter=True, dodge=True, alpha=0.2);

# %%
sns.set(rc={'figure.figsize':(8,5), 'figure.dpi':100})
plt.scatter(y=df['Income'],x=df['age_in_years'], alpha=0.1);
plt.yscale('log')
# plt.yscale('log')

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from math import log

i_max = df_train['Income'].max()
i_min = df_train['Income'].min()
i_dif = i_max - i_min
# Create the Scaler object
scaler = StandardScaler()

le = LabelEncoder()
#Frequency encoding
enc = df.groupby('sourcing_channel').size()
enc = enc / len(df)

def data_transform(data):
    
    data['age_in_years'] = data['age_in_days'].apply(lambda x: x//365)
    
    data['Count_3-6_months_late'] = data['Count_3-6_months_late'].fillna(0)
    
    data['Count_6-12_months_late'] = data['Count_6-12_months_late'].fillna(0)
    
    data['Count_more_than_12_months_late'] = data['Count_more_than_12_months_late'].fillna(0)
    
    data['application_underwriting_score'] = data['application_underwriting_score'].fillna(data['application_underwriting_score'].mean())
    
    data['3_plus_late'] = data['Count_more_than_12_months_late'] + data['Count_6-12_months_late'] + data['Count_3-6_months_late']
    
    data['6_plus_late'] = data['Count_more_than_12_months_late'] + data['Count_6-12_months_late']
    
    data['Count_3-12_months_late'] = data['Count_6-12_months_late'] + data['Count_3-6_months_late']
    
    data['total_count_paid'] = data['3_plus_late'] + data['no_of_premiums_paid']
    
    data['perc_paid_late'] = data['3_plus_late'] / data['total_count_paid']
    
    data['perc_paid_ontime'] = data['no_of_premiums_paid'] / data['total_count_paid']
    
    data['ratio_late_ontime'] = data['3_plus_late'] / data['no_of_premiums_paid']
    
    #data['sourcing_encoded'] = df['sourcing_channel'].map(enc)
    
    data['residence_area_type'] = le.fit_transform(data['residence_area_type'])
    
    #data['sourcing_channel'] = le.fit_transform(data['sourcing_channel'])
    
    data = pd.get_dummies(data)
    
    data['normalized_underwriting_score'] = data['application_underwriting_score'] - 90
    
#     data['age_bin_round'] = np.array(np.floor(np.array(data['age_in_years']) / 10.))
    
    data['per_payment_perc'] = data['perc_premium_paid_by_cash_credit'] / data['total_count_paid']
    
    data['remaining_perc'] = 1 - data['perc_premium_paid_by_cash_credit']
    
    data['late_payments_0-1'] = data['3_plus_late'].apply( lambda x: 1 if x>0 else 0)
    
    #data['Income'] = data['Income'].apply( lambda x: log(x))
    
    #data['age_bin'] = np.array(np.floor(np.array(data['age_in_years']) / 10.))
    
    data = data.drop(['id','age_in_days','perc_premium_paid_by_cash_credit','residence_area_type',
                      'application_underwriting_score','sourcing_channel_B'], axis=1)
    
    
    return data

# %%
data2 = data_transform(df_train.copy())

# %%
data2.head().T
# Out:
#                                          0           1          2           3  \
# Income                         355060.0000 315150.0000 84140.0000 250510.0000
# Count_3-6_months_late               0.0000      0.0000     2.0000      0.0000
# Count_6-12_months_late              0.0000      0.0000     3.0000      0.0000
# Count_more_than_12_months_late      0.0000      0.0000     1.0000      0.0000
# no_of_premiums_paid                13.0000     21.0000     7.0000      9.0000
# target                              1.0000      1.0000     0.0000      1.0000
# age_in_years                       33.0000     59.0000    48.0000     42.0000
# 3_plus_late                         0.0000      0.0000     6.0000      0.0000
# 6_plus_late                         0.0000      0.0000     4.0000      0.0000
# Count_3-12_months_late              0.0000      0.0000     5.0000      0.0000
# total_count_paid                   13.0000     21.0000    13.0000      9.0000
# perc_paid_late                      0.0000      0.0000     0.4615      0.0000
# perc_paid_ontime                    1.0000      1.0000     0.5385      1.0000
# ratio_late_ontime                   0.0000      0.0000     0.8571      0.0000
# sourcing_channel_A                  0.0000      1.0000     0.0000      1.0000
# sourcing_channel_C                  1.0000      0.0000     1.0000      0.0000
# sourcing_channel_D                  0.0000      0.0000     0.0000      0.0000
# sourcing_channel_E                  0.0000      0.0000     0.0000      0.0000
# normalized_underwriting_score       9.0200      9.8900     8.6900      9.5700
# per_payment_perc                    0.0330      0.0005     0.0705      0.0054
# remaining_perc                      0.5710      0.9900     0.0830      0.9510
# late_payments_0-1                   0.0000      0.0000     1.0000      0.0000
#
#                                          4
# Income                         198680.0000
# Count_3-6_months_late               0.0000
# Count_6-12_months_late              0.0000
# Count_more_than_12_months_late      0.0000
# no_of_premiums_paid                12.0000
# target                              1.0000
# age_in_years                       86.0000
# 3_plus_late                         0.0000
# 6_plus_late                         0.0000
# Count_3-12_months_late              0.0000
# total_count_paid                   12.0000
# perc_paid_late                      0.0000
# perc_paid_ontime                    1.0000
# ratio_late_ontime                   0.0000
# sourcing_channel_A                  0.0000
# sourcing_channel_C                  0.0000
# sourcing_channel_D                  0.0000
# sourcing_channel_E                  0.0000
# normalized_underwriting_score       9.8700
# per_payment_perc                    0.0043
# remaining_perc                      0.9480
# late_payments_0-1                   0.0000

# %%
data2.describe().T
# Out:
#                                     count        mean         std        min  \
# Income                         79853.0000 208847.1712 496582.5973 24030.0000
# Count_3-6_months_late          79853.0000      0.2484      0.6911     0.0000
# Count_6-12_months_late         79853.0000      0.0781      0.4363     0.0000
# Count_more_than_12_months_late 79853.0000      0.0599      0.3118     0.0000
# no_of_premiums_paid            79853.0000     10.8639      5.1707     2.0000
# target                         79853.0000      0.9374      0.2422     0.0000
# age_in_years                   79853.0000     51.6074     14.2705    21.0000
# 3_plus_late                    79853.0000      0.3864      1.0433     0.0000
# 6_plus_late                    79853.0000      0.1380      0.6000     0.0000
# Count_3-12_months_late         79853.0000      0.3265      0.8894     0.0000
# total_count_paid               79853.0000     11.2503      5.2805     2.0000
# perc_paid_late                 79853.0000      0.0333      0.0854     0.0000
# perc_paid_ontime               79853.0000      0.9667      0.0854     0.1333
# ratio_late_ontime              79853.0000      0.0472      0.1527     0.0000
# sourcing_channel_A             79853.0000      0.5402      0.4984     0.0000
# sourcing_channel_C             79853.0000      0.1508      0.3578     0.0000
# sourcing_channel_D             79853.0000      0.0947      0.2927     0.0000
# sourcing_channel_E             79853.0000      0.0076      0.0870     0.0000
# normalized_underwriting_score  79853.0000      9.0673      0.7259     1.9000
# per_payment_perc               79853.0000      0.0393      0.0651     0.0000
# remaining_perc                 79853.0000      0.6857      0.3349     0.0000
# late_payments_0-1              79853.0000      0.2030      0.4022     0.0000
#
#                                        25%         50%         75%  \
# Income                         108010.0000 166560.0000 252090.0000
# Count_3-6_months_late               0.0000      0.0000      0.0000
# Count_6-12_months_late              0.0000      0.0000      0.0000
# Count_more_than_12_months_late      0.0000      0.0000      0.0000
# no_of_premiums_paid                 7.0000     10.0000     14.0000
# target                              1.0000      1.0000      1.0000
# age_in_years                       41.0000     51.0000     62.0000
# 3_plus_late                         0.0000      0.0000      0.0000
# 6_plus_late                         0.0000      0.0000      0.0000
# Count_3-12_months_late              0.0000      0.0000      0.0000
# total_count_paid                    8.0000     10.0000     14.0000
# perc_paid_late                      0.0000      0.0000      0.0000
# perc_paid_ontime                    1.0000      1.0000      1.0000
# ratio_late_ontime                   0.0000      0.0000      0.0000
# sourcing_channel_A                  0.0000      1.0000      1.0000
# sourcing_channel_C                  0.0000      0.0000      0.0000
# sourcing_channel_D                  0.0000      0.0000      0.0000
# sourcing_channel_E                  0.0000      0.0000      0.0000
# normalized_underwriting_score       8.8300      9.1800      9.5200
# per_payment_perc                    0.0032      0.0150      0.0479
# remaining_perc                      0.4620      0.8330      0.9660
# late_payments_0-1                   0.0000      0.0000      0.0000
#
#                                          max
# Income                         90262600.0000
# Count_3-6_months_late                13.0000
# Count_6-12_months_late               17.0000
# Count_more_than_12_months_late       11.0000
# no_of_premiums_paid                  60.0000
# target                                1.0000
# age_in_years                        103.0000
# 3_plus_late                          19.0000
# 6_plus_late                          17.0000
# Count_3-12_months_late               17.0000
# total_count_paid                     60.0000
# perc_paid_late                        0.8667
# perc_paid_ontime                      1.0000
# ratio_late_ontime                     6.5000
# sourcing_channel_A                    1.0000
# sourcing_channel_C                    1.0000
# sourcing_channel_D                    1.0000
# sourcing_channel_E                    1.0000
# normalized_underwriting_score         9.8900
# per_payment_perc                      0.5000
# remaining_perc                        1.0000
# late_payments_0-1                     1.0000

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79853 entries, 0 to 79852
# Data columns (total 22 columns):
# Income                            79853 non-null int64
# Count_3-6_months_late             79853 non-null float64
# Count_6-12_months_late            79853 non-null float64
# Count_more_than_12_months_late    79853 non-null float64
# no_of_premiums_paid               79853 non-null int64
# target                            79853 non-null int64
# age_in_years                      79853 non-null int64
# 3_plus_late                       79853 non-null float64
# 6_plus_late                       79853 non-null float64
# Count_3-12_months_late            79853 non-null float64
# total_count_paid                  79853 non-null float64
# perc_paid_late                    79853 non-null float64
# perc_paid_ontime                  79853 non-null float64
# ratio_late_ontime                 79853 non-null float64
# sourcing_channel_A                79853 non-null uint8
# sourcing_channel_C                79853 non-null uint8
# sourcing_channel_D                79853 non-null uint8
# sourcing_channel_E                79853 non-null uint8
# normalized_underwriting_score     79853 non-null float64
# per_payment_perc                  79853 non-null float64
# remaining_perc                    79853 non-null float64
# late_payments_0-1                 79853 non-null int64
# dtypes: float64(13), int64(5), uint8(4)
# memory usage: 11.3 MB

# %%
c_m = data2.corr()
c_m['target'].sort_values()
# Out:
# perc_paid_late                   -0.3601
# 3_plus_late                      -0.3533
# ratio_late_ontime                -0.3332
# Count_3-12_months_late           -0.3308
# 6_plus_late                      -0.3305
# Count_6-12_months_late           -0.2840
# late_payments_0-1                -0.2728
# Count_3-6_months_late            -0.2465
# Count_more_than_12_months_late   -0.2385
# per_payment_perc                 -0.1588
# total_count_paid                 -0.0476
# sourcing_channel_D               -0.0284
# sourcing_channel_C               -0.0216
# sourcing_channel_E               -0.0047
# Income                            0.0165
# no_of_premiums_paid               0.0227
# sourcing_channel_A                0.0364
# normalized_underwriting_score     0.0673
# age_in_years                      0.0951
# remaining_perc                    0.2410
# perc_paid_ontime                  0.3601
# target                            1.0000
# Name: target, dtype: float64

# %%
# min_max_scaler = MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(data2.values)
# X = pd.DataFrame(x_scaled)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV

# %%
X = data2.drop(['target'], axis=1)
y = data2['target']
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2)

# %%
import xgboost as xgb
from sklearn import metrics

# %%
xgc = xgb.XGBClassifier()

# %%
xgc.set_params( **{'colsample_bytree': 0.7,
 'eta': 0.03,
 'gamma': 0.7,
 'max_depth': 2,
 'min_child_weight': 1,
 'n_estimators': 250,
 'subsample': 0.85})
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.7, eta=0.03, gamma=0.7,
#        learning_rate=0.1, max_delta_step=0, max_depth=2,
#        min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.85, verbosity=1)

# %%
xgc.fit(X,y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.7, eta=0.03, gamma=0.7,
#        learning_rate=0.1, max_delta_step=0, max_depth=2,
#        min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.85, verbosity=1)

# %%
pd.DataFrame( xgc.feature_importances_, index=list(X.columns))
# Out:
#                                     0
# Income                         0.0077
# Count_3-6_months_late          0.0252
# Count_6-12_months_late         0.0272
# Count_more_than_12_months_late 0.0028
# no_of_premiums_paid            0.0112
# age_in_years                   0.0114
# 3_plus_late                    0.1324
# 6_plus_late                    0.1781
# Count_3-12_months_late         0.0219
# total_count_paid               0.0145
# perc_paid_late                 0.1357
# perc_paid_ontime               0.1176
# ratio_late_ontime              0.1966
# sourcing_channel_A             0.0026
# sourcing_channel_C             0.0028
# sourcing_channel_D             0.0052
# sourcing_channel_E             0.0022
# normalized_underwriting_score  0.0144
# per_payment_perc               0.0174
# remaining_perc                 0.0731
# late_payments_0-1              0.0000

# %%
pd.Series(xgc.get_booster().get_score(importance_type="gain")).sort_values(ascending=False)
# Out:
# ratio_late_ontime                224.4588
# 6_plus_late                      203.3122
# perc_paid_late                   154.9763
# 3_plus_late                      151.1273
# perc_paid_ontime                 134.2815
# remaining_perc                    83.4954
# Count_6-12_months_late            31.0655
# Count_3-6_months_late             28.7313
# Count_3-12_months_late            24.9805
# per_payment_perc                  19.8452
# total_count_paid                  16.6016
# normalized_underwriting_score     16.4310
# age_in_years                      13.0681
# no_of_premiums_paid               12.7602
# Income                             8.8291
# sourcing_channel_D                 5.8851
# Count_more_than_12_months_late     3.2325
# sourcing_channel_C                 3.2051
# sourcing_channel_A                 2.9399
# sourcing_channel_E                 2.5535
# dtype: float64

# %%
test = df_test.copy()

# %%
test = data_transform(test)

# %%
sub_file = pd.DataFrame(df_test['id'])

# %%
prob_pred = xgc.predict_proba(test)
sub_file['target'] = prob_pred[:,1]

# %%
sub_file.to_csv('solution_opt.csv', index=False)
