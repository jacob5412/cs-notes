# %% [markdown]
# # Pandas: Intro by DataCamp - 1
#
# ## Sorting and Subsetting

# %%
import pandas as pd
import numpy as np

# %%
all_medalists = pd.read_csv('data/all_medalists.csv')

# %%
all_medalists.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ```python
# DataFrame.info(self, verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None) → None
# ```
#
# Print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
all_medalists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# ```python
# DataFrame.describe(self: ~FrameOrSeries, percentiles=None, include=None, exclude=None) → ~FrameOrSeries
# ```
#
# Generate descriptive statistics.
#
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
#
# Analyzes both numeric and object series, as well as DataFrame column sets of mixed data types. The output will vary depending on what is provided. Refer to the notes below for more detail.

# %%
pd.options.display.float_format = '{:.4f}'.format
all_medalists.describe(percentiles= [0,0.25,0.5,0.75,0.9,0.95,0.99,1])
# Out:
#          Edition
# count 29216.0000
# mean   1967.7132
# std      32.4063
# min    1896.0000
# 0%     1896.0000
# 25%    1948.0000
# 50%    1976.0000
# 75%    1996.0000
# 90%    2004.0000
# 95%    2008.0000
# 99%    2008.0000
# 100%   2008.0000
# max    2008.0000

# %% [markdown]
# ```python
# DataFrame.sort_values(self, by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False)
# ```
#
# Sort by the values along either axis.

# %%
all_medalists.sort_values('Edition', ascending = False).head(5)
# Out:
#           City  Edition       Sport       Discipline            Athlete  NOC  \
# 29215  Beijing     2008   Wrestling  Wrestling Gre-R     BAROEV, Khasan  RUS
# 27859  Beijing     2008  Basketball       Basketball  LISINA, Ekaterina  RUS
# 27846  Beijing     2008  Basketball       Basketball         GASOL, Pau  ESP
# 27847  Beijing     2008  Basketball       Basketball    JIMENEZ, Carlos  ESP
# 27848  Beijing     2008  Basketball       Basketball        LOPEZ, Raul  ESP
#
#       Gender       Event Event_gender   Medal
# 29215    Men  96 - 120kg            M  Silver
# 27859  Women  basketball            W  Bronze
# 27846    Men  basketball            M  Silver
# 27847    Men  basketball            M  Silver
# 27848    Men  basketball            M  Silver

# %%
all_medalists[all_medalists.Edition != 2008]
# Out:
#          City  Edition      Sport       Discipline               Athlete  NOC  \
# 0      Athens     1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# 1      Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 2      Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 3      Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 4      Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...       ...      ...        ...              ...                   ...  ...
# 27169  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam  EGY
# 27170  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz  GEO
# 27171  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon  USA
# 27172  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
# 27173  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy  KAZ
#
#       Gender                       Event Event_gender   Medal
# 0        Men              100m freestyle            M    Gold
# 1        Men              100m freestyle            M  Silver
# 2        Men  100m freestyle for sailors            M  Bronze
# 3        Men  100m freestyle for sailors            M    Gold
# 4        Men  100m freestyle for sailors            M  Silver
# ...      ...                         ...          ...     ...
# 27169    Men                   84 - 96kg            M    Gold
# 27170    Men                   84 - 96kg            M  Silver
# 27171    Men                  96 - 120kg            M  Bronze
# 27172    Men                  96 - 120kg            M    Gold
# 27173    Men                  96 - 120kg            M  Silver
#
# [27174 rows x 10 columns]

# %%
all_medalists[(all_medalists.Edition <= 2008) & (all_medalists.NOC.isin(['NOC','AUT','GRE']))]
# Out:
#           City  Edition      Sport Discipline                 Athlete  NOC  \
# 1       Athens     1896   Aquatics   Swimming        HERSCHMANN, Otto  AUT
# 2       Athens     1896   Aquatics   Swimming       DRIVAS, Dimitrios  GRE
# 3       Athens     1896   Aquatics   Swimming      MALOKINIS, Ioannis  GRE
# 4       Athens     1896   Aquatics   Swimming      CHASAPIS, Spiridon  GRE
# 5       Athens     1896   Aquatics   Swimming   CHOROPHAS, Efstathios  GRE
# ...        ...      ...        ...        ...                     ...  ...
# 28749  Beijing     2008     Rowing     Rowing    POLYMEROS, Vasileios  GRE
# 28837  Beijing     2008    Sailing    Sailing        BEKATOROU, Sofia  GRE
# 28838  Beijing     2008    Sailing    Sailing    KRAVARIOTI, Virginia  GRE
# 28839  Beijing     2008    Sailing    Sailing     PAPADOPOULOU, Sofia  GRE
# 28975  Beijing     2008  Taekwondo  Taekwondo  NIKOLAIDIS, Alexandros  GRE
#
#       Gender                           Event Event_gender   Medal
# 1        Men                  100m freestyle            M  Silver
# 2        Men      100m freestyle for sailors            M  Bronze
# 3        Men      100m freestyle for sailors            M    Gold
# 4        Men      100m freestyle for sailors            M  Silver
# 5        Men                 1200m freestyle            M  Bronze
# ...      ...                             ...          ...     ...
# 28749    Men  lightweight double sculls (2x)            M  Silver
# 28837  Women              Yngling - Keelboat            W  Bronze
# 28838  Women              Yngling - Keelboat            W  Bronze
# 28839  Women              Yngling - Keelboat            W  Bronze
# 28975    Men                         + 80 kg            M  Silver
#
# [291 rows x 10 columns]

# %% [markdown]
# ## Adding new columns

# %%
all_medalists['NA_col'] = np.nan
all_medalists.head(4)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal  NA_col
# 0              100m freestyle            M    Gold     nan
# 1              100m freestyle            M  Silver     nan
# 2  100m freestyle for sailors            M  Bronze     nan
# 3  100m freestyle for sailors            M    Gold     nan

# %% [markdown]
# ## Summary Statistics

# %%
sales = pd.read_csv('data/sales/sales.csv', parse_dates = ['month'])

# %%
sales.head()
# Out:
#   month  eggs    salt  spam
# 0   Jan    47 12.0000    17
# 1   Feb   110 50.0000    31
# 2   Mar   221 89.0000    72
# 3   Apr    77 87.0000    20
# 4   May   132     nan    52

# %%
# Print the head of the sales DataFrame
print(sales.head())

# Print the info about the sales DataFrame
print(sales.info())

# Print the mean of spam
print(sales.spam.mean())

# Print the median of spam
print(sales.spam.median())
# Out:
#   month  eggs    salt  spam
# 0   Jan    47 12.0000    17
# 1   Feb   110 50.0000    31
# 2   Mar   221 89.0000    72
# 3   Apr    77 87.0000    20
# 4   May   132     nan    52
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# month    6 non-null object
# eggs     6 non-null int64
# salt     5 non-null float64
# spam     6 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 320.0+ bytes
# None
# 41.166666666666664
# 41.5

# %%
# Print the maximum of the month column
print(sales.month.max())

# Print the minimum of the month column
print(sales.month.min())
# Out:
# May
# Apr

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)
    
# Print IQR of the spam column
print(sales[['eggs','salt','spam']].agg([iqr, np.median]))
# Out:
#            eggs    salt    spam
# iqr    101.5000 37.0000 31.5000
# median 121.0000 60.0000 41.5000

# %% [markdown]
# ## Cumulative statistics

# %%
# Sort sales_1_1 by month
sales_1_1 = sales.sort_values('month')

# Get the cumulative sum of spam, add as cum_spam col
sales_1_1['cum_spam'] = sales_1_1.spam.cumsum()

# Get the cumulative max of spam, add as cum_max_spam col
sales_1_1['cum_max_spam'] = sales_1_1.spam.cummax()

# See the columns you calculated
print(sales_1_1[["month", "cum_spam", "cum_max_spam", "spam"]])
# Out:
#   month  cum_spam  cum_max_spam  spam
# 3   Apr        20            20    20
# 1   Feb        51            31    31
# 0   Jan        68            31    17
# 5   Jun       123            55    55
# 2   Mar       195            72    72
# 4   May       247            72    52

# %% [markdown]
# ## Dropping Duplicates

# %%
titanic = pd.read_csv('data/titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic_unique = titanic.drop_duplicates(subset = ['cabin'])

# %%
titanic_unique.head()
# Out:
#    pclass  survived                               name     sex     age  sibsp  \
# 0       1         1      Allen, Miss. Elisabeth Walton  female 29.0000      0
# 1       1         1     Allison, Master. Hudson Trevor    male  0.9200      1
# 5       1         1                Anderson, Mr. Harry    male 48.0000      0
# 6       1         1  Andrews, Miss. Kornelia Theodosia  female 63.0000      1
# 7       1         0             Andrews, Mr. Thomas Jr    male 39.0000      0
#
#    parch  ticket     fare    cabin embarked boat  body  \
# 0      0   24160 211.3375       B5        S    2   nan
# 1      2  113781 151.5500  C22 C26        S   11   nan
# 5      0   19952  26.5500      E12        S    3   nan
# 6      0   13502  77.9583       D7        S   10   nan
# 7      0  112050   0.0000      A36        S  NaN   nan
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI

# %% [markdown]
# ## Counting Categorical Variables
#
# ```python
# Series.value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# ```
#
# Return a Series containing counts of unique values.
#
# The resulting object will be in descending order so that the first element is the most frequently-occurring element. Excludes NA values by default.

# %%
titanic_unique['sex'].value_counts()
# Out:
# male      131
# female     56
# Name: sex, dtype: int64

# %%
titanic_unique['sex'].value_counts(ascending=True)
# Out:
# female     56
# male      131
# Name: sex, dtype: int64

# %%
titanic_unique['sex'].value_counts(normalize=True)
# Out:
# male     0.7005
# female   0.2995
# Name: sex, dtype: float64

# %% [markdown]
# ## Grouped Summary Statistics

# %%
titanic.groupby('sex')['fare'].agg([min, max, sum])
# Out:
#           min      max        sum
# sex
# female 6.7500 512.3292 21528.3130
# male   0.0000 512.3292 22022.1739

# %% [markdown]
# ## Pivot Tables
#
# ```python
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False) → 'DataFrame'
# ```
#
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.

# %%
titanic.pivot_table(index = 'sex', values = 'fare', aggfunc = 'mean')
# Out:
#           fare
# sex
# female 46.1981
# male   26.1546

# %%
titanic.pivot_table(index = 'sex', values = 'fare', aggfunc = ['mean','median'])
# Out:
#           mean  median
#           fare    fare
# sex
# female 46.1981 23.0000
# male   26.1546 11.8875

# %%
titanic.pivot_table(index = 'sex', values = 'fare', columns =  'pclass', aggfunc = ['mean','median'], margins = True)
# Out:
#            mean                          median
# pclass        1       2       3     All       1       2       3     All
# sex
# female 109.4124 23.2348 15.3242 46.1981 80.9291 23.0000 10.4896 23.0000
# male    69.8884 19.9049 12.4155 26.1546 49.5042 13.0000  7.8958 11.8875
# All     87.5090 21.1792 13.3029 33.2955 60.0000 15.0458  8.0500 14.4542

# %%
titanic_sex_fare_boat = titanic.pivot_table(index = 'sex', values = 'fare', columns =  'boat', aggfunc = ['mean','median'], 
                    fill_value = 'None')

# %%
titanic_sex_fare_boat
# Out:
#           mean                                                                 \
# boat         1      10      11      12      13  13 15 13 15 B      14      15
# sex
# female 48.2646 70.5076 36.3928 20.2963 13.3072   None    None 35.4318 13.9048
# male   46.1236 22.0617 40.8786 14.5250 21.2083 7.5104  7.7500 24.1130 10.5302
#
#                ...  median                                                 \
# boat    15 16  ...       6       7       8    8 10       9       A      B
# sex            ...
# female 7.7500  ... 78.8500 71.0000 86.5000 26.5500 15.7500 17.9000   None
# male     None  ... 18.8625 29.7000    None    None 13.0000  7.7958 8.0500
#
#
# boat         C     C D       D
# sex
# female  8.0500 20.5250 22.3583
# male   15.4937 20.5250 26.0000
#
# [2 rows x 54 columns]

# %% [markdown]
# ## Calculating on a pivot table

# %%
titanic_sex_fare_boat.mean(axis = 'index')
# Out:
#         boat
# mean    1       47.1941
#         10      46.2847
#         11      38.6357
#         12      17.4107
#         13      17.2577
#         14      29.7724
#         15      12.2175
#         16      14.4651
#         2       66.1633
#         3      147.1338
#         4      111.3451
#         5       60.1520
#         5 7     52.0000
#         6       54.7028
#         7       53.5226
#         9       23.7921
#         A       21.7299
#         C       22.2340
#         C D     20.5250
#         D       35.1849
# median  1       51.8531
#         10      24.1625
#         11      18.1802
#         12      17.7625
#         13      10.1813
#         14      22.1250
#         15       9.5291
#         16      13.1917
#         2       61.1625
#         3       95.7500
#         4       67.0958
#         5       53.9980
#         5 7     52.0000
#         6       48.8562
#         7       50.3500
#         9       14.3750
#         A       12.8479
#         C       11.7719
#         C D     20.5250
#         D       24.1791
# dtype: float64

# %%
titanic_sex_fare_boat.mean(axis = 'columns')
# Out:
# sex
# female   48.5107
# male     30.0703
# dtype: float64
